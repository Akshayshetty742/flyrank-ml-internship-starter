# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane

**Lane:** Google Search Ranking & Discoverability

I chose this lane because I want to understand how search ranking affects website visibility and click-through rate (CTR). By analyzing search performance data, I can identify which webpages should be improved first. This helps make better SEO decisions based on data instead of guesswork.
"""))
# Out:
# ## My Lane
#
# **Lane:** Google Search Ranking & Discoverability
#
# I chose this lane because I want to understand how search ranking affects website visibility and click-through rate (CTR). By analyzing search performance data, I can identify which webpages should be improved first. This helps make better SEO decisions based on data instead of guesswork.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Research Question

**Research Question**

How does a webpage's search ranking affect its click-through rate (CTR), and which pages should be prioritized for SEO improvement?

**Decision**

Identify which webpages should be optimized first.

**Who acts on it?**

SEO specialists and website owners.

**Cost of a wrong decision**

Optimizing the wrong pages wastes time and resources and can reduce potential website traffic.
"""))
# Out:
# ## Research Question
#
# **Research Question**
#
# How does a webpage's search ranking affect its click-through rate (CTR), and which pages should be prioritized for SEO improvement?
#
# **Decision**
#
# Identify which webpages should be optimized first.
#
# **Who acts on it?**
#
# SEO specialists and website owners.
#
# **Cost of a wrong decision**
#
# Optimizing the wrong pages wastes time and resources and can reduce potential website traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Supporting Numbers

From the starter dataset:

- Mean CTR for **Page 1** = **0.3548**
- Mean CTR for **Top 3** = **0.3341**
- Mean CTR for **Deep pages** = **0.0554**

These values show that webpages appearing higher in search results receive much higher click-through rates than pages ranked deeper.
"""))
# Out:
# ## Supporting Numbers
#
# From the starter dataset:
#
# - Mean CTR for **Page 1** = **0.3548**
# - Mean CTR for **Top 3** = **0.3341**
# - Mean CTR for **Deep pages** = **0.0554**
#
# These values show that webpages appearing higher in search results receive much higher click-through rates than pages ranked deeper.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Careful Words

### What I can claim
- I observed that webpages with higher search rankings generally have higher click-through rates (CTR) in the starter dataset.
- The analysis can help support SEO decisions by identifying pages that may benefit from optimization.
- The findings show an association between ranking position and CTR in this dataset.

### What I cannot claim
- I cannot claim that improving a page's ranking will always increase CTR.
- I cannot predict Google's ranking algorithm or guarantee future rankings.
- I cannot prove a cause-and-effect relationship using this dataset alone.
"""))
# Out:
# ## Careful Words
#
# ### What I can claim
# - I observed that webpages with higher search rankings generally have higher click-through rates (CTR) in the starter dataset.
# - The analysis can help support SEO decisions by identifying pages that may benefit from optimization.
# - The findings show an association between ranking position and CTR in this dataset.
#
# ### What I cannot claim
# - I cannot claim that improving a page's ranking will always increase CTR.
# - I cannot predict Google's ranking algorithm or guarantee future rankings.
# - I cannot prove a cause-and-effect relationship using this dataset alone.
