# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# My Lane as an ML Task

**Lane:** Google Search Ranking & Discoverability

**ML Task Type:** Ranking

The goal is to rank webpages based on their potential to improve click-through rate (CTR). Instead of manually deciding which pages should be optimized, a machine learning model can rank pages according to their expected impact on search performance.
"""))
# Out:
# # My Lane as an ML Task
#
# **Lane:** Google Search Ranking & Discoverability
#
# **ML Task Type:** Ranking
#
# The goal is to rank webpages based on their potential to improve click-through rate (CTR). Instead of manually deciding which pages should be optimized, a machine learning model can rank pages according to their expected impact on search performance.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# Target or Proxy

Target:

Predict which webpages are most likely to benefit from SEO improvements.

Proxy:

Click-through rate (CTR) and search ranking position are used as indicators of webpage performance.
"""))
# Out:
# # Target or Proxy
#
# Target:
#
# Predict which webpages are most likely to benefit from SEO improvements.
#
# Proxy:
#
# Click-through rate (CTR) and search ranking position are used as indicators of webpage performance.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# Success Metric

A successful model should correctly identify webpages that have the highest potential for improvement.

The model will be considered useful if it helps prioritize SEO work more effectively than random or manual selection.
"""))
# Out:
# # Success Metric
#
# A successful model should correctly identify webpages that have the highest potential for improvement.
#
# The model will be considered useful if it helps prioritize SEO work more effectively than random or manual selection.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# Unit of Analysis

Each row in the dataset represents one webpage.

Important columns include:

- Search Position
- Click Through Rate (CTR)
- Search Volume
- Impressions
- Clicks

The model analyzes one webpage at a time.
"""))
# Out:
# # Unit of Analysis
#
# Each row in the dataset represents one webpage.
#
# Important columns include:
#
# - Search Position
# - Click Through Rate (CTR)
# - Search Volume
# - Impressions
# - Clicks
#
# The model analyzes one webpage at a time.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
# Why Machine Learning?

A fixed rule cannot consider many factors simultaneously.

Machine learning can analyze multiple features such as impressions, clicks, CTR, search volume, and ranking position to identify hidden patterns and recommend which webpages should be optimized first.
"""))
# Out:
# # Why Machine Learning?
#
# A fixed rule cannot consider many factors simultaneously.
#
# Machine learning can analyze multiple features such as impressions, clicks, CTR, search volume, and ranking position to identify hidden patterns and recommend which webpages should be optimized first.

# %% [markdown]
# from IPython.display import Markdown, display
#
# display(Markdown("""
# # Self Check
#
# ✔ I identified the ML task type.
#
# ✔ I explained the prediction target.
#
# ✔ I defined a success metric.
#
# ✔ I described the unit of analysis.
#
# ✔ I explained why machine learning is more useful than a simple fixed rule.
# """))
